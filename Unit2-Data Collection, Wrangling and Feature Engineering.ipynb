# %% [markdown]
# # 👩🏻‍💻 Unit 2: Data Collection, Wrangling and Feature Engineering In Machine Learning
# - Lesson 2.1 – Get Financial Data Using SimFin Platform
# - Lesson 2.2 – Read Financial Data in CSV Format Using Pandas
# - Lesson 2.3 – Perform Data Merging
# - Lesson 2.4 – Locate, Count, and Handle Missing Datasets
# - Lesson 2.5 – Perform One-Hot Encoding
# - Lesson 2.6 – Perform Feature Engineering

# %% [markdown]
# ---

# %% [markdown]
# ## What is Data Wrangling?
# - Data wranging involves cleaning and organizing raw dataset by merging multiple sources of data, handling missing values, and converting data from one format to another.
# ## What is Feature Engineering?
# - Feature engieering involves transforming features in a dataset with the goal of improving the performance of downstream machine learning models. Feature engineering involves feature selection, scaling, and creating new features from existing ones.

# %% [markdown]
# ### 🎬 Lesson 2.1: Get Financial Data Using SimFin Platform

# %% [markdown]
# !pip install simfin

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# - Link to SimFin Platform: www.simfin.com
# - Link to documentation and tutorials:https://github.com/SimFin/simfin-tutorials

# %%
import simfin as sf
import pandas as pd
import numpy as np
import os

# %%
sf.set_api_key('d816079c-ec3b-4519-8849-38274ea087ba')
dir_path = './simfin_data'
if not os.path.exists(dir_path): 
    os.mkdir(dir_path)
sf.set_data_dir(dir_path)

# %%
income_df = sf.load_income(variant='quarterly', market = 'us').reset_index()
income_df.head(5)
# Out:
# Dataset "us-income-quarterly" on disk (0 days old).
# - Loading from disk ... Done!
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 0      A  2019-10-31     45846      USD         2019            Q4
# 1      A  2020-01-31     45846      USD         2020            Q1
# 2      A  2020-04-30     45846      USD         2020            Q2
# 3      A  2020-07-31     45846      USD         2020            Q3
# 4      A  2020-10-31     45846      USD         2020            Q4
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2019-12-19    2019-08-30     309000000.0       313000000.0  ...
# 1   2020-03-03    2021-03-02     310000000.0       313000000.0  ...
# 2   2020-06-01    2021-06-01     309000000.0       312000000.0  ...
# 3   2020-09-01    2021-09-01     309000000.0       312000000.0  ...
# 4   2020-12-18    2021-09-01     308000000.0       311000000.0  ...
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# ...

# %%
cashflow_df = sf.load_cashflow(variant = 'quarterly', market = 'us').reset_index()
cashflow_df.head(5)
# Out:
# Dataset "us-cashflow-quarterly" on disk (0 days old).
# Done!ding from disk ...
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 0      A  2019-10-31     45846      USD         2019            Q4
# 1      A  2020-01-31     45846      USD         2020            Q1
# 2      A  2020-04-30     45846      USD         2020            Q2
# 3      A  2020-07-31     45846      USD         2020            Q3
# 4      A  2020-10-31     45846      USD         2020            Q4
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2019-12-19    2019-08-30     309000000.0       313000000.0  ...
# 1   2020-03-03    2021-03-02     310000000.0       313000000.0  ...
# 2   2020-06-01    2021-03-02     309000000.0       312000000.0  ...
# 3   2020-09-01    2021-06-01     309000000.0       312000000.0  ...
# 4   2020-12-18    2021-09-01     308000000.0       311000000.0  ...
#
# ...

# %%
balance_df = sf.load_balance(variant = 'quarterly', market = 'us').reset_index()
balance_df.head(5)
# Out:
# Dataset "us-balance-quarterly" on disk (0 days old).
# Done!ding from disk ...
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 0      A  2019-10-31     45846      USD         2019            Q4
# 1      A  2020-01-31     45846      USD         2020            Q1
# 2      A  2020-04-30     45846      USD         2020            Q2
# 3      A  2020-07-31     45846      USD         2020            Q3
# 4      A  2020-10-31     45846      USD         2020            Q4
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2019-12-19    2020-12-18     309000000.0       313000000.0  ...
# 1   2020-03-03    2020-03-03     310000000.0       313000000.0  ...
# 2   2020-06-01    2020-06-01     309000000.0       312000000.0  ...
# 3   2020-09-01    2020-09-01     309000000.0       312000000.0  ...
# 4   2020-12-18    2021-12-17     308000000.0       311000000.0  ...
#
#    Short Term Debt  Total Current Liabilities  Long Term Debt  \
# ...

# %% [markdown]
# **❇️ PRACTICE OPPORTUNITY:**
# - Load the annual cashflow statements for US companies using SimFin and store them in cashflow_annual_df Pandas DataFrame
# - What is the memory usage of the cashflow_annual_df Pandas DataFrame?

# %%
# Practice 1:
cashflow_annual_df = sf.load_cashflow(variant = 'annual', market = 'us').reset_index()
cashflow_annual_df.head(5)
# Out:
# Dataset "us-cashflow-annual" on disk (0 days old).
# Done!ding from disk ...
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 0      A  2019-10-31     45846      USD         2019            FY
# 1      A  2020-10-31     45846      USD         2020            FY
# 2      A  2021-10-31     45846      USD         2021            FY
# 3      A  2022-10-31     45846      USD         2022            FY
# 4      A  2023-10-31     45846      USD         2023            FY
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2019-12-19    2021-12-17     314000000.0       318000000.0  ...
# 1   2020-12-18    2022-12-21     309000000.0       312000000.0  ...
# 2   2021-12-17    2023-12-20     305000000.0       307000000.0  ...
# 3   2022-12-21    2024-12-20     304000000.0       307000000.0  ...
# 4   2023-12-20    2024-12-20     294000000.0       296000000.0  ...
#
# ...

# %%
# Practice 2:
# 1. Quick summary of memory usage
cashflow_annual_df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17611 entries, 0 to 17610
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Ticker                                     17608 non-null  object
#  1   Report Date                                17611 non-null  datetime64[ns]
#  2   SimFinId                                   17611 non-null  int64
#  3   Currency                                   17611 non-null  object
#  4   Fiscal Year                                17611 non-null  int64
#  5   Fiscal Period                              17611 non-null  object
#  6   Publish Date                               17611 non-null  datetime64[ns]
#  7   Restated Date                              17611 non-null  datetime64[ns]
#  8   Shares (Basic)                             17440 non-null  float64
# ...

# %%
# 2. Exact memory usage in bytes
cashflow_annual_df.memory_usage(deep=True).sum()
# Out:
# np.int64(6263308)

# %%
# 3. Break down per column
cashflow_annual_df.memory_usage(deep=True)
# Out:
# Index                                           132
# Ticker                                       927043
# Report Date                                  140888
# SimFinId                                     140888
# Currency                                     915772
# Fiscal Year                                  140888
# Fiscal Period                                898161
# Publish Date                                 140888
# Restated Date                                140888
# Shares (Basic)                               140888
# Shares (Diluted)                             140888
# Net Income/Starting Line                     140888
# Depreciation & Amortization                  140888
# Non-Cash Items                               140888
# Change in Working Capital                    140888
# Change in Accounts Receivable                140888
# Change in Inventories                        140888
# Change in Accounts Payable                   140888
# ...

# %% [markdown]
# #### Memory usage optimization:
# - float64 → float32
# - int64 → int32 / int16
# - object → category

# %%
import pandas as pd
import numpy as np

def reduce_memory_usage(df_orig: pd.DataFrame, verbose=True) -> pd.DataFrame:
    """
    Automatically optimize DataFrame memory usage:
    - Downcast int/float columns
    - Convert object columns to category (if the ratio of unique values < 50%)
    - Display memory usage before and after optimization
    """
    df = df_orig.copy()
    start_mem = df.memory_usage(deep=True).sum() / 1024**2
    
    for col in df.columns:
        col_type = df[col].dtype

        if pd.api.types.is_numeric_dtype(col_type):
            # Process integers
            if pd.api.types.is_integer_dtype(col_type):
                df[col] = pd.to_numeric(df[col], downcast="integer")
            # Process floats
            elif pd.api.types.is_float_dtype(col_type):
                df[col] = pd.to_numeric(df[col], downcast="float")
        
        # Process objects
        elif col_type == "object":
            num_unique = df[col].nunique()
            num_total = len(df[col])
            if num_unique / num_total < 0.5:  
                df[col] = df[col].astype("category")
    
    end_mem = df.memory_usage(deep=True).sum() / 1024**2
    
    if verbose:
        print(f"Memory usage before optimization: {start_mem:.2f} MB")
        print(f"Memory usage after optimization: {end_mem:.2f} MB")
        print(f"has reduced {(start_mem - end_mem) / start_mem * 100:.1f}%")
    
    return 
reduce_memory_usage(cashflow_annual_df)
# Out:
# Memory usage before optimization: 5.97 MB
# Memory usage after optimization: 3.61 MB
# has reduced 39.6%

# %% [markdown]
# ---

# %% [markdown]
# ### 🎬 Lesson 2.2: Read Financial Data in CSV Format Using Pandas

# %%
income_df = pd.read_csv(r'./data/unit2/income_statement.csv')
balance_df = pd.read_csv(r'./data/unit2/balance_sheet.csv')
cashflow_df = pd.read_csv(r'./data/unit2/cashflow_statement.csv')

# %%
income_df.head(3)
# Out:
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period  \
# 0      A   1/31/2017     45846      USD         2017            Q1
# 1      A   4/30/2017     45846      USD         2017            Q2
# 2      A   7/31/2017     45846      USD         2017            Q3
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0     3/8/2017      3/6/2018     322000000.0       326000000.0  ...
# 1     6/6/2017     5/31/2018     321000000.0       325000000.0  ...
# 2     9/6/2017     8/30/2018     321000000.0       326000000.0  ...
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                  -13000000.0            -16000000.0
# 1                  -10000000.0            -15000000.0
# 2                   -8000000.0            -13000000.0
#
#    Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                   193000000                      NaN             193000000
# ...

# %%
companies_info_df = pd.read_csv(r'./data/unit2/companies_information.csv')
industries_info_df = pd.read_csv(r'./data/unit2/industries_information.csv')

# %%
# set the maximum number of rows to be displayed in a Pandas DataFrame to 70
pd.options.display.max_rows = 70
industries_info_df.head(10)
# Out:
#    IndustryId       Sector                       Industry
# 0      100001  Industrials            Industrial Products
# 1      100002  Industrials              Business Services
# 2      100003  Industrials     Engineering & Construction
# 3      100004  Industrials               Waste Management
# 4      100005  Industrials        Industrial Distribution
# 5      100006  Industrials                       Airlines
# 6      100007  Industrials       Consulting & Outsourcing
# 7      100008  Industrials            Aerospace & Defense
# 8      100009  Industrials  Farm & Construction Machinery
# 9      100010  Industrials     Transportation & Logistics

# %%
industries_info_df.Sector.nunique(), industries_info_df.Sector.unique()
# Out:
# (12,
#  array(['Industrials', 'Technology', 'Consumer Defensive',
#         'Consumer Cyclical', 'Financial Services', 'Utilities',
#         'Healthcare', 'Energy', 'Business Services', 'Real Estate',
#         'Basic Materials', 'Other'], dtype=object))

# %% [markdown]
# **❇️ PRACTICE OPPORTUNITY:**
# - Use the head() method to display the first 15 rows in the "companies_info_df" Pandas DataFrame
# - What is the ticker symbol and SimFinId for APPLE INC?

# %%
# Practice 1:
companies_info_df.head(15)
# Out:
#    Ticker  SimFinId                      Company Name  IndustryId
# 0       A     45846          AGILENT TECHNOLOGIES INC    106001.0
# 1     A21   1333027                      Li Auto Inc.         NaN
# 2      AA    367153                        Alcoa Corp    110004.0
# 3     AAL     68568      American Airlines Group Inc.    100006.0
# 4    AAMC    847094  Altisource Asset Management Corp    104001.0
# 5    AAME    450021            ATLANTIC AMERICAN CORP    104004.0
# 6     AAN    441241             Aaron's Company, Inc.    100007.0
# 7    AAOI    671827     APPLIED OPTOELECTRONICS, INC.    101004.0
# 8    AAON    919501                          AAON INC    100001.0
# 9     AAP    184955            ADVANCE AUTO PARTS INC    103002.0
# 10   AAPL    111052                         APPLE INC    101001.0
# 11    AAT    919944       American Assets Trust, Inc.    109001.0
# 12   AAWW    762204  ATLAS AIR WORLDWIDE HOLDINGS INC    100010.0
# ...

# %%
# Practice 2:
companies_info_df.loc[companies_info_df['Company Name'] == 'APPLE INC']
# Out:
#    Ticker  SimFinId Company Name  IndustryId
# 10   AAPL    111052    APPLE INC    101001.0

# %% [markdown]
# ---

# %% [markdown]
# ### 🎬 Lesson 2.3: Perform Data Merging

# %%
companies_info_df.head(3)
# Out:
#   Ticker  SimFinId              Company Name  IndustryId
# 0      A     45846  AGILENT TECHNOLOGIES INC    106001.0
# 1    A21   1333027              Li Auto Inc.         NaN
# 2     AA    367153                Alcoa Corp    110004.0

# %%
industries_info_df.head(3)
# Out:
#    IndustryId       Sector                    Industry
# 0      100001  Industrials         Industrial Products
# 1      100002  Industrials           Business Services
# 2      100003  Industrials  Engineering & Construction

# %%
companies_industries_df = pd.merge(companies_info_df, industries_info_df, on='IndustryId', how='left')
companies_industries_df.head(3)
# Out:
#   Ticker  SimFinId              Company Name  IndustryId           Sector  \
# 0      A     45846  AGILENT TECHNOLOGIES INC    106001.0       Healthcare
# 1    A21   1333027              Li Auto Inc.         NaN              NaN
# 2     AA    367153                Alcoa Corp    110004.0  Basic Materials
#
#                          Industry
# 0  Medical Diagnostics & Research
# 1                             NaN
# 2                 Metals & Mining

# %%
eps_df = pd.read_csv(r'./data/unit2/eps_df.csv')
eps_df.head(3)
# Out:
#    Earnings Per Share, Basic Ticker  Fiscal Year Fiscal Period
# 0                    0.52174      A         2017            Q1
# 1                    0.51090      A         2017            Q2
# 2                    0.54517      A         2017            Q3

# %%
cashflow_df = cashflow_df.drop(columns = ['Report Date', 
                                          'Currency', 
                                          'Publish Date', 
                                          'Restated Date', 
                                          'Shares (Basic)', 
                                          'Shares (Diluted)', 
                                          'Depreciation & Amortization'])
balance_df = balance_df.drop(columns = ['Report Date', 
                                        'Currency', 
                                        'Publish Date', 
                                        'Restated Date', 
                                        'Shares (Basic)', 
                                        'Shares (Diluted)'])

# %%
# Find join key columns between dataframes
df_pair = [(companies_industries_df, income_df), (income_df, cashflow_df), \
           (cashflow_df, balance_df), (balance_df, eps_df)]
for df1, df2 in df_pair:
    print("dataframe has common columns: {}".format((set(df1.columns) & set(df2.columns))))
# Out:
# dataframe has common columns: {'SimFinId', 'Ticker'}
# dataframe has common columns: {'Fiscal Period', 'Ticker', 'Fiscal Year', 'SimFinId'}
# dataframe has common columns: {'Fiscal Period', 'Ticker', 'Fiscal Year', 'SimFinId'}
# dataframe has common columns: {'Fiscal Period', 'Fiscal Year', 'Ticker'}

# %%
merged_df = companies_industries_df.merge(income_df, on = ['Ticker','SimFinId'], how = 'left')\
                                   .merge(cashflow_df, on = ['Ticker','SimFinId', 'Fiscal Year','Fiscal Period'], how = 'left')\
                                   .merge(balance_df, on = ['Ticker','SimFinId','Fiscal Year','Fiscal Period'], how = 'left')\
                                   .merge(eps_df, on = ['Ticker','Fiscal Year','Fiscal Period'], how = 'left')
merged_df.head(5)
# Out:
#   Ticker  SimFinId              Company Name  IndustryId      Sector  \
# 0      A     45846  AGILENT TECHNOLOGIES INC    106001.0  Healthcare
# 1      A     45846  AGILENT TECHNOLOGIES INC    106001.0  Healthcare
# 2      A     45846  AGILENT TECHNOLOGIES INC    106001.0  Healthcare
# 3      A     45846  AGILENT TECHNOLOGIES INC    106001.0  Healthcare
# 4      A     45846  AGILENT TECHNOLOGIES INC    106001.0  Healthcare
#
#                          Industry Report Date Currency  Fiscal Year  \
# 0  Medical Diagnostics & Research   1/31/2017      USD       2017.0
# 1  Medical Diagnostics & Research   4/30/2017      USD       2017.0
# 2  Medical Diagnostics & Research   7/31/2017      USD       2017.0
# 3  Medical Diagnostics & Research  10/31/2017      USD       2017.0
# 4  Medical Diagnostics & Research   1/31/2018      USD       2018.0
#
#   Fiscal Period  ... Total Current Liabilities Long Term Debt  \
# 0            Q1  ...              1.089000e+09   1.802000e+09
# ...

# %%
merged_df = merged_df.drop(columns = ['SimFinId','IndustryId'])
merged_df.shape
# Out:
# (42162, 68)

# %%
# Verify if the ticker unique value counts in merged_df is the same as in companies_indusries_df while using left join
assert len(merged_df['Ticker'].unique().tolist()) == \
len(companies_industries_df['Ticker'].unique().tolist())

# %% [markdown]
# **❇️ PRACTICE OPPORTUNITY:**
# - Merge the "industries_info_df" and "companies_info_df" Pandas DataFrames using "right" join type instead of "left" and place the answer in a new Pandas DataFrame titled "companies_industries_right_df"

# %%
# Practice 1:
companies_industries_right_df = pd.merge(industries_info_df, companies_info_df, \
                                         on='IndustryId', how='right')

# %% [markdown]
# ---

# %% [markdown]
# ### 🎬 Lesson 2.4: Locate, Count, and Handle Missing Datasets
